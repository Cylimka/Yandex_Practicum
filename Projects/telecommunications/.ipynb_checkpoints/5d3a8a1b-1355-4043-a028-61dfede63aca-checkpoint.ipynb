# %% [markdown]
# # «ТелеДом»  борьба с оттоком клиентов

# %% [markdown]
# Оператор связи «ТелеДом» хочет бороться с оттоком клиентов. Для этого его сотрудники начнут предлагать промокоды и специальные условия всем, кто планирует отказаться от услуг связи. Чтобы заранее находить таких пользователей, «ТелеДому» нужна модель, которая будет предсказывать, разорвёт ли абонент договор. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и услугах. Ваша задача — обучить на этих данных модель для прогноза оттока клиентов.

# %% [markdown]
# ## Знакомство с данными

# %% [markdown]
# Установии/обновим библиотеки

# %%
# !pip install phik
# !pip install scikit-learn==1.1.3
# Out:
# Requirement already satisfied: phik in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (0.12.3)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from phik) (1.24.3)
# Requirement already satisfied: scipy>=1.5.2 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from phik) (1.10.1)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from phik) (1.5.3)
# Requirement already satisfied: matplotlib>=2.2.3 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from phik) (3.7.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from phik) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from pandas>=0.25.1->phik) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)
# Requirement already satisfied: scikit-learn==1.1.3 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (1.1.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from scikit-learn==1.1.3) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from scikit-learn==1.1.3) (1.10.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from scikit-learn==1.1.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cylib\appdata\local\anaconda3\lib\site-packages (from scikit-learn==1.1.3) (2.2.0)

# %% [markdown]
# Подключение библиотек

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import phik
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (roc_auc_score,
                             accuracy_score,
                             roc_curve,
                             confusion_matrix)
from sklearn.model_selection import (GridSearchCV, train_test_split)
from catboost import CatBoostClassifier
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler,
    OrdinalEncoder
)
from sklearn.pipeline import make_pipeline
from phik.report import plot_correlation_matrix
from phik import report


RANDOM_STATE=27112023

# %% [markdown]
# Загрузим данные

# %%
df_contract = pd.read_csv('contract_new.csv')
df_personal = pd.read_csv('personal_new.csv')
df_internet = pd.read_csv('internet_new.csv')
df_phone = pd.read_csv('phone_new.csv')

# %% [markdown]
# Выведем первые 5 строк каждого датафрейма и посмотрим какие данные они хранят

# %%
df_contract.head(5)
# Out:
#    customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01      No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01      No        One year               No
# 2  3668-QPYBK  2019-10-01      No  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01      No        One year               No
# 4  9237-HQITU  2019-09-01      No  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges
# 0           Electronic check           29.85        31.04
# 1               Mailed check           56.95      2071.84
# 2               Mailed check           53.85       226.17
# 3  Bank transfer (automatic)           42.30       1960.6
# 4           Electronic check           70.70        353.5

# %% [markdown]
# * **customerID** — идентификатор абонента
# * **BeginDate** — дата начала действия договора
# * **EndDate** — дата окончания действия договора
# * **Type** — тип оплаты: раз в год-два или ежемесячно
# * **PaperlessBilling** — электронный расчётный лист
# * **PaymentMethod** — тип платежа
# * **MonthlyCharges** — расходы за месяц
# * **TotalCharges** — общие расходы абонента

# %%
df_personal.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %% [markdown]
# * **customerID** — идентификатор пользователя;
# * **gender** — пол;
# * **SeniorCitizen** — является ли абонент пенсионером;
# * **Partner** — есть ли у абонента супруг или супруга;
# * **Dependents** — есть ли у абонента дети.

# %%
df_internet.head(5)
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No

# %% [markdown]
# * **customerID** — идентификатор пользователя;
# * **InternetService** — тип подключения;
# * **OnlineSecurity** — блокировка опасных сайтов;
# * **OnlineBackup** — облачное хранилище файлов для резервного копирования данных;
# * **DeviceProtection** — антивирус;
# * **TechSupport** — выделенная линия технической поддержки;
# * **StreamingTV** — стриминговое телевидение;
# * **StreamingMovies** — каталог фильмов.

# %%
df_phone.head(5)
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %% [markdown]
# * **customerID** — идентификатор пользователя;
# * **MultipleLines** — подключение телефона к нескольким линиям одновременно.

# %% [markdown]
# Посмотрим информацию о каждом датафрейме, для этого напишем мини-функцию которая будет выводить случайные 2 строчки, информацию по типам и количеству наблюдений и общей статистике по датафрейму, которого приняла на вход эта функция.

# %%
def info(df):
    display(df.sample(2, random_state=RANDOM_STATE))
    df.info()
    display(df.describe(include='all'))
    print(f'Количество явных дубликатов: {df.duplicated().sum()}')
    print(f'Количество дубликатов по столбцу customerID: {df.duplicated(subset="customerID").sum()}')

# %% [markdown]
# общая информация по датафрейму **df_contract**

# %%
info(df_contract)
# Out:
#       customerID   BeginDate EndDate            Type PaperlessBilling  \
# 1434  1571-SAVHK  2018-10-01      No  Month-to-month              Yes
# 1490  8016-ZMGMO  2014-08-01      No        One year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges
# 1434               Mailed check           99.95      1631.18
# 1490  Bank transfer (automatic)           70.85      4769.62
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
#         customerID   BeginDate EndDate            Type PaperlessBilling  \
# count         7043        7043    7043            7043             7043
# unique        7043          77      67               3                2
# top     7590-VHVEG  2014-02-01      No  Month-to-month              Yes
# freq             1         366    5942            3875             4171
# mean           NaN         NaN     NaN             NaN              NaN
# std            NaN         NaN     NaN             NaN              NaN
# min            NaN         NaN     NaN             NaN              NaN
# 25%            NaN         NaN     NaN             NaN              NaN
# 50%            NaN         NaN     NaN             NaN              NaN
# 75%            NaN         NaN     NaN             NaN              NaN
# max            NaN         NaN     NaN             NaN              NaN
#
#            PaymentMethod  MonthlyCharges TotalCharges
# count               7043     7043.000000         7043
# unique                 4             NaN         6658
# top     Electronic check             NaN
# freq                2365             NaN           11
# mean                 NaN       64.761692          NaN
# std                  NaN       30.090047          NaN
# min                  NaN       18.250000          NaN
# 25%                  NaN       35.500000          NaN
# 50%                  NaN       70.350000          NaN
# 75%                  NaN       89.850000          NaN
# max                  NaN      118.750000          NaN
# Количество явных дубликатов: 0
# Количество дубликатов по столбцу customerID: 0

# %% [markdown]
# * Пропусков нет
# * Дубликатов нет
# * Типы данных можно изменить в столбцах
#     * **BeginDate** - object  -> datetime
#     * **TotalCharges** - object -> float64
# * Нужно привести названия столбцов к стилю snake_case

# %%
info(df_personal)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 1434  1571-SAVHK    Male              0      No         No
# 1490  8016-ZMGMO  Female              1     Yes         No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
#         customerID gender  SeniorCitizen Partner Dependents
# count         7043   7043    7043.000000    7043       7043
# unique        7043      2            NaN       2          2
# top     7590-VHVEG   Male            NaN      No         No
# freq             1   3555            NaN    3641       4933
# mean           NaN    NaN       0.162147     NaN        NaN
# std            NaN    NaN       0.368612     NaN        NaN
# min            NaN    NaN       0.000000     NaN        NaN
# 25%            NaN    NaN       0.000000     NaN        NaN
# 50%            NaN    NaN       0.000000     NaN        NaN
# 75%            NaN    NaN       0.000000     NaN        NaN
# max            NaN    NaN       1.000000     NaN        NaN
# Количество явных дубликатов: 0
# Количество дубликатов по столбцу customerID: 0

# %% [markdown]
# * Пропусков нет
# * Дубликатов нет
# * типы данных трогать не нужно
# * Нужно привести названия столбцов к стилю snake_case

# %%
info(df_internet)
# Out:
#       customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 2927  9822-WMWVG     Fiber optic            Yes          Yes              Yes
# 2789  4317-VTEOA             DSL             No          Yes               No
#
#      TechSupport StreamingTV StreamingMovies
# 2927         Yes         Yes              No
# 2789          No          No              No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB
#         customerID InternetService OnlineSecurity OnlineBackup  \
# count         5517            5517           5517         5517
# unique        5517               2              2            2
# top     7590-VHVEG     Fiber optic             No           No
# freq             1            3096           3498         3088
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies
# count              5517        5517        5517            5517
# unique                2           2           2               2
# top                  No          No          No              No
# freq               3095        3473        2810            2785
# Количество явных дубликатов: 0
# Количество дубликатов по столбцу customerID: 0

# %% [markdown]
# * Пропусков нет
# * Дубликатов нет
# * Типы данных трогать не нужно
# * Нужно привести названия столбцов к стилю snake_case

# %%
info(df_phone)
# Out:
#       customerID MultipleLines
# 4705  2080-CAZNM           Yes
# 1068  3992-YWPKO           Yes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
#         customerID MultipleLines
# count         6361          6361
# unique        6361             2
# top     5575-GNVDE            No
# freq             1          3390
# Количество явных дубликатов: 0
# Количество дубликатов по столбцу customerID: 0

# %% [markdown]
# * Пропусков нет
# * Дубликатов нет
# * Типы данных трогать не нужно
# * Нужно привести названия столбцов к стилю snake_case

# %% [markdown]
# ### Выводы по знакомству с данными:
# * Пропусков в данных нет
# * Дубликатов в данных нет
# * Типы данных надо изменить в таблице df_contract
#     * **BeginDate** - object  -> datetime
#     * **TotalCharges** - object -> float64
# * Все названия столбцов надо привести к стилю snake_case

# %% [markdown]
# ## Предобработка

# %% [markdown]
# ### Изменим названия столбцов

# %% [markdown]
# Приведем названия столбцов в **df_contract** к стилю *snake_case*

# %%
df_contract.columns = ['customer_id', 'begin_date', 'end_date', 'type', 'paperless_billing',
       'payment_method', 'monthly_charges', 'total_charges']
df_contract.columns
# Out:
# Index(['customer_id', 'begin_date', 'end_date', 'type', 'paperless_billing',
#        'payment_method', 'monthly_charges', 'total_charges'],
#       dtype='object')

# %% [markdown]
# Названия столбцов изменились применим ту же самую операцию на другие датафреймы

# %% [markdown]
# **df_personal**

# %%
df_personal.columns = ['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents']
df_personal.columns
# Out:
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents'], dtype='object')

# %% [markdown]
# **df_internet**

# %%
df_internet.columns = ['customer_id', 'internet_service', 'online_security', 'online_backup',
       'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies']
df_internet.columns
# Out:
# Index(['customer_id', 'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv',
#        'streaming_movies'],
#       dtype='object')

# %% [markdown]
# **df_phone**

# %%
df_phone.columns = ['customer_id', 'multiple_lines']
df_phone.columns
# Out:
# Index(['customer_id', 'multiple_lines'], dtype='object')

# %% [markdown]
# Как мы видим названия столбцов были изменены, можно приступать к изменению типов данных

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Посмотрим на типы данных в **df_contract**

# %%
df_contract.dtypes
# Out:
# customer_id           object
# begin_date            object
# end_date              object
# type                  object
# paperless_billing     object
# payment_method        object
# monthly_charges      float64
# total_charges         object
# dtype: object

# %% [markdown]
# Посмотрим есть ли пропуски в cтолбцe **total_charges**

# %%
df_contract[df_contract['total_charges'] == ' ']
# Out:
#      customer_id  begin_date end_date      type paperless_billing  \
# 488   4472-LVYGI  2020-02-01       No  Two year               Yes
# 753   3115-CZMZD  2020-02-01       No  Two year                No
# 936   5709-LVOEQ  2020-02-01       No  Two year                No
# 1082  4367-NUYAO  2020-02-01       No  Two year                No
# 1340  1371-DWPAZ  2020-02-01       No  Two year                No
# 3331  7644-OMVMY  2020-02-01       No  Two year                No
# 3826  3213-VVOLG  2020-02-01       No  Two year                No
# 4380  2520-SGTTA  2020-02-01       No  Two year                No
# 5218  2923-ARZLG  2020-02-01       No  One year               Yes
# 6670  4075-WKNIU  2020-02-01       No  Two year                No
# 6754  2775-SEFEE  2020-02-01       No  Two year               Yes
#
#                  payment_method  monthly_charges total_charges
# 488   Bank transfer (automatic)            52.55
# 753                Mailed check            20.25
# 936                Mailed check            80.85
# 1082               Mailed check            25.75
# 1340    Credit card (automatic)            56.05
# 3331               Mailed check            19.85
# 3826               Mailed check            25.35
# 4380               Mailed check            20.00
# 5218               Mailed check            19.70
# 6670               Mailed check            73.35
# 6754  Bank transfer (automatic)            61.90

# %% [markdown]
# Как мы видим у нас есть пропуски в столбце **total_chargees**, Скорее всего так получилось из-за того что пользователи только заключили договор, напишем в **total_chargees**  0

# %%
df_contract['total_charges'] = df_contract[['total_charges']].replace(" ", 0).astype('float64')

# %% [markdown]
# Изменим тип в столбце **begin_date** на *datetime*, для начала посмотрим все уникальные значения в этом столбце

# %%
df_contract['begin_date'].unique()
# Out:
# array(['2020-01-01', '2017-04-01', '2019-10-01', '2016-05-01',
#        '2019-09-01', '2019-03-01', '2018-04-01', '2019-04-01',
#        '2017-07-01', '2014-12-01', '2019-01-01', '2018-10-01',
#        '2015-04-01', '2015-09-01', '2018-01-01', '2014-05-01',
#        '2015-10-01', '2014-03-01', '2018-05-01', '2019-11-01',
#        '2019-02-01', '2016-01-01', '2017-08-01', '2015-12-01',
#        '2014-02-01', '2018-06-01', '2019-12-01', '2017-11-01',
#        '2019-06-01', '2016-04-01', '2017-02-01', '2018-12-01',
#        '2014-04-01', '2018-09-01', '2014-11-01', '2016-07-01',
#        '2015-02-01', '2018-07-01', '2014-08-01', '2016-03-01',
#        '2018-08-01', '2014-10-01', '2015-06-01', '2016-08-01',
#        '2019-05-01', '2017-03-01', '2016-02-01', '2017-09-01',
#        '2014-09-01', '2017-12-01', '2016-12-01', '2017-06-01',
#        '2015-05-01', '2016-10-01', '2016-09-01', '2019-08-01',
#        '2019-07-01', '2017-05-01', '2017-10-01', '2014-07-01',
#        '2018-03-01', '2015-01-01', '2018-11-01', '2015-03-01',
#        '2018-02-01', '2016-06-01', '2015-08-01', '2015-11-01',
#        '2014-06-01', '2017-01-01', '2015-07-01', '2020-02-01',
#        '2016-11-01', '2013-11-01', '2014-01-01', '2013-10-01',
#        '2013-12-01'], dtype=object)

# %% [markdown]
# Можем заметить что все уникальные даты начинаются с первого дня месяца

# %%
df_contract['begin_date'] = pd.to_datetime(df_contract['begin_date'], format='%Y-%m-%d')

# %% [markdown]
# Переведем даты в тип datetime

# %%
df_contract.dtypes
# Out:
# customer_id                  object
# begin_date           datetime64[ns]
# end_date                     object
# type                         object
# paperless_billing            object
# payment_method               object
# monthly_charges             float64
# total_charges               float64
# dtype: object

# %% [markdown]
# ### Объеденение данных

# %% [markdown]
# Создадим датафрейм **df** в котором будут данные из датафреймов: **df_contract**, **df_internet**, **df_personal**, **df_phone**

# %%
df = df_contract.copy()
df = (df.merge(df_internet, on ='customer_id', how = 'outer')
        .merge(df_personal, on ='customer_id', how = 'outer')
        .merge(df_phone, on ='customer_id', how = 'outer'))

# %% [markdown]
# Выведем первые 5 строк нового датафрейма **df**

# %%
df.head(5)
# Out:
#   customer_id begin_date end_date            type paperless_billing  \
# 0  7590-VHVEG 2020-01-01       No  Month-to-month               Yes
# 1  5575-GNVDE 2017-04-01       No        One year                No
# 2  3668-QPYBK 2019-10-01       No  Month-to-month               Yes
# 3  7795-CFOCW 2016-05-01       No        One year                No
# 4  9237-HQITU 2019-09-01       No  Month-to-month               Yes
#
#               payment_method  monthly_charges  total_charges internet_service  \
# 0           Electronic check            29.85          31.04              DSL
# 1               Mailed check            56.95        2071.84              DSL
# 2               Mailed check            53.85         226.17              DSL
# 3  Bank transfer (automatic)            42.30        1960.60              DSL
# 4           Electronic check            70.70         353.50      Fiber optic
#
#   online_security online_backup device_protection tech_support streaming_tv  \
# 0              No           Yes                No           No           No
# 1             Yes            No               Yes           No           No
# 2             Yes           Yes                No           No           No
# 3             Yes            No               Yes          Yes           No
# 4              No            No                No           No           No
#
#   streaming_movies  gender  senior_citizen partner dependents multiple_lines
# 0               No  Female               0     Yes         No            NaN
# 1               No    Male               0      No         No             No
# 2               No    Male               0      No         No             No
# 3               No    Male               0      No         No            NaN
# 4               No  Female               0      No         No             No

# %% [markdown]
# Выведем общую информацию о новом датафрейме

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   datetime64[ns]
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   float64
#  8   internet_service   5517 non-null   object
#  9   online_security    5517 non-null   object
#  10  online_backup      5517 non-null   object
#  11  device_protection  5517 non-null   object
#  12  tech_support       5517 non-null   object
#  13  streaming_tv       5517 non-null   object
#  14  streaming_movies   5517 non-null   object
#  15  gender             7043 non-null   object
#  16  senior_citizen     7043 non-null   int64
#  17  partner            7043 non-null   object
#  18  dependents         7043 non-null   object
#  19  multiple_lines     6361 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 1.1+ MB

# %% [markdown]
# Как мы видим у нас появились пропущенные значения, скорее всего они появились из-за того что не все таблицы содержали данные о том или ином пользователе. Допустим если человек не подключил услуги интернета (тойсь его нет в таблице *df_internet*), то в новой таблице у него будут пропуски в столбцах которые были в **df_internet**

# %% [markdown]
# Посмотрим на количество пропусков в данных

# %%
df.isna().sum()
# Out:
# customer_id             0
# begin_date              0
# end_date                0
# type                    0
# paperless_billing       0
# payment_method          0
# monthly_charges         0
# total_charges           0
# internet_service     1526
# online_security      1526
# online_backup        1526
# device_protection    1526
# tech_support         1526
# streaming_tv         1526
# streaming_movies     1526
# gender                  0
# senior_citizen          0
# partner                 0
# dependents              0
# multiple_lines        682
# dtype: int64

# %% [markdown]
# Посмотрим какая разница между количеством записей в таблице **df_contract** и **df_internet, чтобы подтвердить наше предположение

# %%
df_contract.shape[0] - df_internet.shape[0]
# Out:
# 1526

# %% [markdown]
# Проверим разницу между **df_contract** и **df_phone**

# %%
df_contract.shape[0] - df_phone.shape[0]
# Out:
# 682

# %% [markdown]
# Как мы видим наше предположение подтвердилось

# %% [markdown]
# Так как из-за соединения данных у нас появились 1526 пропусков, с людьми которые не используют интернет, заполним все пропуски строкой *NCI* - *not connected internet*

# %%
df[df_internet.columns] = df[df_internet.columns].fillna('NCI')

# %% [markdown]
# Проверим количество пропусков

# %%
df.isna().sum()
# Out:
# customer_id            0
# begin_date             0
# end_date               0
# type                   0
# paperless_billing      0
# payment_method         0
# monthly_charges        0
# total_charges          0
# internet_service       0
# online_security        0
# online_backup          0
# device_protection      0
# tech_support           0
# streaming_tv           0
# streaming_movies       0
# gender                 0
# senior_citizen         0
# partner                0
# dependents             0
# multiple_lines       682
# dtype: int64

# %% [markdown]
# Отлично мы избавились от всех пропусков которые возникли в результате присоединения таблицы **df_internet**, сделаем то же самое и для столбцов таблицы **df_phone**, только изменим строку которой мы заменяем пропуски на NCP

# %%
df[df_phone.columns] = df[df_phone.columns].fillna('NCP')

# %% [markdown]
# Проверим количество пропусков

# %%
df.isna().sum()
# Out:
# customer_id          0
# begin_date           0
# end_date             0
# type                 0
# paperless_billing    0
# payment_method       0
# monthly_charges      0
# total_charges        0
# internet_service     0
# online_security      0
# online_backup        0
# device_protection    0
# tech_support         0
# streaming_tv         0
# streaming_movies     0
# gender               0
# senior_citizen       0
# partner              0
# dependents           0
# multiple_lines       0
# dtype: int64

# %% [markdown]
# Пропусков нет можно двигаться дальше.

# %% [markdown]
# ### Целевая переменная

# %% [markdown]
# Нам нужно создать целевую переменную, так как нас интересует предсказание того будет ли договор расторгнут или нет, посмотрим на уникальные значения в столбце **end_date**, в котором показана дата окончания действия договора

# %%
df.end_date.unique()
# Out:
# array(['No', '2017-05-01', '2016-03-01', '2018-09-01', '2018-11-01',
#        '2018-12-01', '2019-08-01', '2018-07-01', '2017-09-01',
#        '2015-09-01', '2016-07-01', '2016-06-01', '2018-03-01',
#        '2019-02-01', '2018-06-01', '2019-06-01', '2020-01-01',
#        '2019-11-01', '2016-09-01', '2015-06-01', '2016-12-01',
#        '2019-05-01', '2019-04-01', '2017-06-01', '2017-08-01',
#        '2018-04-01', '2018-08-01', '2018-02-01', '2019-07-01',
#        '2015-12-01', '2014-06-01', '2018-10-01', '2019-01-01',
#        '2017-07-01', '2017-12-01', '2018-05-01', '2015-11-01',
#        '2019-10-01', '2019-03-01', '2016-02-01', '2016-10-01',
#        '2018-01-01', '2017-11-01', '2015-10-01', '2019-12-01',
#        '2015-07-01', '2017-04-01', '2015-02-01', '2017-03-01',
#        '2016-05-01', '2016-11-01', '2015-08-01', '2019-09-01',
#        '2017-10-01', '2017-02-01', '2016-08-01', '2016-04-01',
#        '2015-05-01', '2014-09-01', '2014-10-01', '2017-01-01',
#        '2015-03-01', '2015-01-01', '2016-01-01', '2015-04-01',
#        '2014-12-01', '2014-11-01'], dtype=object)

# %% [markdown]
# Как мы можем заметить в столбце **end_date** есть даты и значение *No*
# * Если значение в **end_date** равно *No*, то в столбце **target** будет 0
# * Если значение в **end_date** не равно *No*, то в столбце **target** будет 1

# %%
df.loc[df['end_date'] == 'No','target'] = 0
df.loc[df['end_date'] != 'No','target'] = 1
df['target'] = df['target'].astype('int8')
df[['end_date','target']].sample(10,random_state=RANDOM_STATE)
# Out:
#         end_date  target
# 1434          No       0
# 1490          No       0
# 2231          No       0
# 3614          No       0
# 5287          No       0
# 202   2016-07-01       1
# 1572          No       0
# 6629          No       0
# 552           No       0
# 5855          No       0

# %%
# код ментора для объяснения
(df['end_date'] != 'No').astype(int)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: end_date, Length: 7043, dtype: int32

# %% [markdown]
# Как мы видим алгоритм работает правильно, посмотрим на баланс классов в целевой переменной

# %%
plt.figure(figsize = (14,7))
sns.countplot(data=df, x='target', hue="target").set(ylabel='Кол-во значений');
plt.legend(['Расторгнул договор', 'Не расторгнул договор']);

# %% [markdown]
# Соотношение не ушедших к ушедшим пользователям  1:5

# %% [markdown]
# ### Создание новых признаков

# %% [markdown]
# #### end_begin_diff

# %% [markdown]
# Создадим новый столбец который будет показывать какое количество дней прошло между днем заключения договора и его расторжением.
# Если договор не был расторгнут, то будем считать что в столбце **end_date** лежит актуальная дата об данных нам договорах - 1 февраля 2020

# %%
df['end_date'] = df['end_date'].replace('No', '2020-02-01')
df['end_date'] = pd.to_datetime(df['end_date'], format='%Y-%m-%d')

# %% [markdown]
# Создадим столбец **end_begin_diff** и выведем 5 строк датафрейма

# %%
df['end_begin_diff'] = (df['end_date'] - df['begin_date']).astype('timedelta64[D]')
df[['begin_date', 'end_date', 'end_begin_diff']].head(5)
# Out:
#   begin_date   end_date  end_begin_diff
# 0 2020-01-01 2020-02-01            31.0
# 1 2017-04-01 2020-02-01          1036.0
# 2 2019-10-01 2020-02-01           123.0
# 3 2016-05-01 2020-02-01          1371.0
# 4 2019-09-01 2020-02-01           153.0

# %% [markdown]
# Успешно создали столбец

# %% [markdown]
# ### Выводы по предобработке
# * Привели названия столбцов к стилю snake_case
# * Изменили типы данных
# * Объединили данные нам датафреймы в один датафрейм **df**
# * Определили целевую переменную по столбцу *end_date*
# * Создали новый признак *end_begin_diff*, который показывает сколько прошло времени с момента начала использования услуг оператора и до конца/текущего дня

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Посмотрим на приток и отток пользователей

# %% [markdown]
# Для начала создадим датафрейм в котором будут данные до 2020 года, я не думаю что его стоит учитывать так как идет только 2 месяц этого года и выше мы назначили всем не расторгнутым договорам февраль этого года

# %%
year_df = df.loc[df.end_date.dt.year != 2020].copy()
year_df.loc[:, 'year_end'] = year_df.end_date.dt.year
year_df.loc[:, 'year_begin'] = year_df.begin_date.dt.year

# %% [markdown]
# Построим графики

# %%
fig, ax = plt.subplots(1,2,figsize=(20,8)) 
sns.countplot(data=year_df, x='year_begin', ax=ax[0]).set(title='Диаграмма притока пользователей',
                                                          ylabel='Кол-во пользователей',
                                                          xlabel='Год',
                                                          yticks=range(0,451,50));
sns.countplot(data=year_df, x='year_end', ax=ax[1]).set(title='Диаграмма оттока пользователей',
                                                        ylabel='Кол-во пользователей',
                                                        xlabel='Год',
                                                        yticks=range(0,401,50));

# %% [markdown]
# Графики выглядят не утешительно:
# * С каждым годом все меньше людей начинают пользоваться услугами оператора связи
# * С каждым годом все больше людей расторгают договоры с оператором

# %% [markdown]
# ### Дополнительные услуги

# %% [markdown]
# Посмотрим зависит ли количество подключенных услуг из таблицы **df_internet** на целевую переменную

# %% [markdown]
# Напишем функцию **count_services** которая будет возвращать количество подключенных услуг у пользователя

# %%
def count_services(row):
    return row[row == 'Yes'].count()

# %% [markdown]
# Применим функцию к нашему датафрейму и сохраним в столбец **count_services**

# %%
df['count_services'] = df[['online_security', 'online_backup',
                           'device_protection', 'tech_support',
                           'streaming_tv', 'streaming_movies']].apply(count_services, axis=1)

# %% [markdown]
# ### Подключенные услуги

# %% [markdown]
# Как мы помним не у всех пользователей были подключены услуги интернета и телефонии, посмотрим как различается соотношение целевого признака для:
# * Всех пользователей
# * Тех кому подключены услуги интернета
# * Тех кому подключены услуги телефонии

# %% [markdown]
# Все пользователи

# %%
df.target.value_counts(normalize=True)
# Out:
# 0    0.843675
# 1    0.156325
# Name: target, dtype: float64

# %% [markdown]
# Пользователи у который подключены услуги интернета

# %%
df.query('customer_id in @df_internet["customer_id"].values').target.value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 df.query('customer_id in @df_internet["customer_id"].values').target.value_counts(normalize=True)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4474, in DataFrame.query(self, expr, inplace, **kwargs)
#    4472 kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473 kwargs["target"] = None
# -> 4474 res = self.eval(expr, **kwargs)
#    4476 try:
#    4477     result = self.loc[res]
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4612, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4609     kwargs["target"] = self
#    4610 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4612 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:353, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     344 # get our (possibly passed-in) scope
#     345 env = ensure_scope(
#     346     level + 1,
#     347     global_dict=global_dict,
#    (...)
#     350     target=target,
#     351 )
# --> 353 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     355 # construct the engine and evaluate the parsed expression
#     356 eng = ENGINES[engine]
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:813, in Expr.__init__(self, expr, engine, parser, env, level)
#     811 self.parser = parser
#     812 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 813 self.terms = self.parse()
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:832, in Expr.parse(self)
#     828 def parse(self):
#     829     """
#     830     Parse an expression.
#     831     """
# --> 832     return self._visitor.visit(self.expr)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:723, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     721     op = self.translate_In(ops[0])
#     722     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 723     return self.visit(binop)
#     725 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     726 left = node.left
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:536, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     535 def visit_BinOp(self, node, **kwargs):
# --> 536     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     537     left, right = self._maybe_downcast_constants(left, right)
#     538     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:458, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     456     left = self.visit(node.left, side="left")
#     457 if right is None:
# --> 458     right = self.visit(node.right, side="right")
#     459 op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     460 return op, op_class, left, right
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:645, in BaseExprVisitor.visit_Attribute(self, node, **kwargs)
#     642 ctx = node.ctx
#     643 if isinstance(ctx, ast.Load):
#     644     # resolve the value
# --> 645     resolved = self.visit(value).value
#     646     try:
#     647         v = getattr(resolved, attr)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:579, in BaseExprVisitor.visit_Subscript(self, node, **kwargs)
#     577 value = self.visit(node.value)
#     578 slobj = self.visit(node.slice)
# --> 579 result = pd_eval(
#     580     slobj, local_dict=self.env, engine=self.engine, parser=self.parser
#     581 )
#     582 try:
#     583     # a Term instance
#     584     v = value.value[result]
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:358, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     356 eng = ENGINES[engine]
#     357 eng_inst = eng(parsed_expr)
# --> 358 ret = eng_inst.evaluate()
#     360 if parsed_expr.assigner is None:
#     361     if multi_line:
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\engines.py:81, in AbstractEngine.evaluate(self)
#      78     self.result_type, self.aligned_axes = align_terms(self.expr.terms)
#      80 # make sure no names in resolvers and locals/globals clash
# ---> 81 res = self._evaluate()
#      82 return reconstruct_object(
#      83     self.result_type, res, self.aligned_axes, self.expr.terms.return_type
#      84 )
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\engines.py:122, in NumExprEngine._evaluate(self)
#     120 scope = env.full_scope
#     121 _check_ne_builtin_clash(self.expr)
# --> 122 return ne.evaluate(s, local_dict=scope)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\numexpr\necompiler.py:835, in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     833 _numexpr_last = dict(ex=compiled_ex, argnames=names, kwargs=kwargs)
#     834 with evaluate_lock:
# --> 835     return compiled_ex(*arguments, **kwargs)
#
# ValueError: data type must provide an itemsize

# %% [markdown]
# Пользователи у которых подключены услуги телефонии

# %%
df.query('customer_id in @df_phone["customer_id"].values').target.value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df.query('customer_id in @df_phone["customer_id"].values').target.value_counts(normalize=True)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4474, in DataFrame.query(self, expr, inplace, **kwargs)
#    4472 kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473 kwargs["target"] = None
# -> 4474 res = self.eval(expr, **kwargs)
#    4476 try:
#    4477     result = self.loc[res]
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4612, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4609     kwargs["target"] = self
#    4610 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4612 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:353, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     344 # get our (possibly passed-in) scope
#     345 env = ensure_scope(
#     346     level + 1,
#     347     global_dict=global_dict,
#    (...)
#     350     target=target,
#     351 )
# --> 353 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     355 # construct the engine and evaluate the parsed expression
#     356 eng = ENGINES[engine]
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:813, in Expr.__init__(self, expr, engine, parser, env, level)
#     811 self.parser = parser
#     812 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 813 self.terms = self.parse()
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:832, in Expr.parse(self)
#     828 def parse(self):
#     829     """
#     830     Parse an expression.
#     831     """
# --> 832     return self._visitor.visit(self.expr)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:723, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     721     op = self.translate_In(ops[0])
#     722     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 723     return self.visit(binop)
#     725 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     726 left = node.left
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:536, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     535 def visit_BinOp(self, node, **kwargs):
# --> 536     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     537     left, right = self._maybe_downcast_constants(left, right)
#     538     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:458, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     456     left = self.visit(node.left, side="left")
#     457 if right is None:
# --> 458     right = self.visit(node.right, side="right")
#     459 op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     460 return op, op_class, left, right
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:645, in BaseExprVisitor.visit_Attribute(self, node, **kwargs)
#     642 ctx = node.ctx
#     643 if isinstance(ctx, ast.Load):
#     644     # resolve the value
# --> 645     resolved = self.visit(value).value
#     646     try:
#     647         v = getattr(resolved, attr)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:579, in BaseExprVisitor.visit_Subscript(self, node, **kwargs)
#     577 value = self.visit(node.value)
#     578 slobj = self.visit(node.slice)
# --> 579 result = pd_eval(
#     580     slobj, local_dict=self.env, engine=self.engine, parser=self.parser
#     581 )
#     582 try:
#     583     # a Term instance
#     584     v = value.value[result]
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:358, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     356 eng = ENGINES[engine]
#     357 eng_inst = eng(parsed_expr)
# --> 358 ret = eng_inst.evaluate()
#     360 if parsed_expr.assigner is None:
#     361     if multi_line:
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\engines.py:81, in AbstractEngine.evaluate(self)
#      78     self.result_type, self.aligned_axes = align_terms(self.expr.terms)
#      80 # make sure no names in resolvers and locals/globals clash
# ---> 81 res = self._evaluate()
#      82 return reconstruct_object(
#      83     self.result_type, res, self.aligned_axes, self.expr.terms.return_type
#      84 )
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\engines.py:122, in NumExprEngine._evaluate(self)
#     120 scope = env.full_scope
#     121 _check_ne_builtin_clash(self.expr)
# --> 122 return ne.evaluate(s, local_dict=scope)
#
# File c:\Users\cylib\AppData\Local\anaconda3\Lib\site-packages\numexpr\necompiler.py:835, in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     833 _numexpr_last = dict(ex=compiled_ex, argnames=names, kwargs=kwargs)
#     834 with evaluate_lock:
# --> 835     return compiled_ex(*arguments, **kwargs)
#
# ValueError: data type must provide an itemsize

# %% [markdown]
# Как мы видим между всеми пользователями и теми у кого подключен интернет есть разница в соотношение целевого признака - те у кого подключен интернет чаще уходят. Добавим в нашу таблицу новый признак, подключен ли у пользователя интернет

# %%
df.loc[df.query('customer_id in @df_internet["customer_id"].values').index, 'internet_connected'] = 1
df.internet_connected = df.internet_connected.fillna(0)

# %% [markdown]
# ### Корреляция признаков

# %% [markdown]
# Перед тем как строить матрицу корреляции из датафрейма нужно убрать признаки непригодные для машинного обучения
# * customer_id - уникальный идентификатор клиента
# * begin_date - дата заключения контракта
# * end_date - дата окончания контракта

# %% [markdown]
# в

# %%
df = df.drop(['customer_id','begin_date', 'end_date', 'gender'], axis=1)

# %% [markdown]
# Посмотрим на матрицу корреляции *phik*

# %%
phik_overview = df.phik_matrix(interval_cols=['monthly_charges', 'total_charges',
                                              'end_begin_diff'])
phik_overview.round(2);

# %% [markdown]
# <div class="alert alert-block alert-danger">
# ❌ <s><b>Ревью 1</b>:
#
# - Как говорили на вводном вебинаре, при вызове phik_matrix в параметер interval_cols нужно передать список имен числовых признаков. Сейчас к ним была ошибочно причислена категориальная целевая переменная 'target'. Это может исказить корреляции.
# - Перед построением матрицы корреляций из датафрейма нужно убрать признаки, непригодные для машинного обучения: уникальный идентификатор клиента (уже удален), абсолютные даты заключения и окончания контракта.</s>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Исправил
# </div>

# %% [markdown]
# Посмотрим на нашу матрицу

# %%
plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Blues", 
                        title=r"Корреляция $\phi_K$", 
                        fontsize_factor=0.8, 
                        figsize=(12, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# Избавимся от мультиколлинеарности и признаков с очень низкой корреляцией с целевой переменной:
# * streaming_tv
# * streaming_movies
# * online_backup
# * tech_support
# * device_protection
# * online_security
# * internet_service
# * type
# * paperless_billing
# * dependents
# * internet_connected

# %%
df.dtypes
# Out:
# type                   object
# paperless_billing      object
# payment_method         object
# monthly_charges       float64
# total_charges         float64
# internet_service       object
# online_security        object
# online_backup          object
# device_protection      object
# tech_support           object
# streaming_tv           object
# streaming_movies       object
# senior_citizen          int64
# partner                object
# dependents             object
# multiple_lines         object
# target                   int8
# end_begin_diff        float64
# count_services          int64
# internet_connected    float64
# dtype: object

# %%
df = df.drop(['streaming_tv', 'streaming_movies', 'online_backup',
             'tech_support', 'device_protection', 'online_security', 'internet_service',
             'internet_connected', 'dependents', 'paperless_billing', 'type'],
           axis=1)

# %% [markdown]
# Посмотрим на матрицу корреляции еще раз

# %%
phik_overview = df.phik_matrix(interval_cols=['monthly_charges', 'total_charges',
                                              'end_begin_diff'])
phik_overview.round(2)

plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Blues", 
                        title=r"Корреляция $\phi_K$", 
                        fontsize_factor=0.8, 
                        figsize=(12, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <b>Ревью 2</b>: Как писал выше, тепловую карту корреляций нужно не только вывести, но и на основе её анализа предложить признаки, которые будут использоваться для обучения модели. Целесообразно избавиться от мультиколлинеарности и признаков с очень низкой корреляцией с целевой переменной. Сейчас некоторые признаки сильно мультиколлинеарны.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Испраил, произошла ситуация, что я удалил признак который сам и создал. Надо ли удалять то как я создавал его или оставить и такое норма "Методом проб и ошибок было установлено что признак не подходит"
# <div class="alert alert-block alert-success">
# ✔️ <b>Ревью 3</b>:
#
# Заранее ведь невозможно знать о силе признака. Иногда в экспериментах создают много признаков, но на основе корреляционного анализа и других методов отбора признаков оставляют только те, у которых предсказательная сила выше. Отбор признаков можно делать разными способами, например:
# - анализ корреляций
# - анализ значимости признаков на этапе обучения (не теста) с отбрасыванием малозначимых без ухудшения качества модели
# - отбор признаков можно вставить в конвейер, задавая правила отбора в гиперпараметрах, диапазоны которых даже можно включить в сетку подбора на кросс-валидации, вот [документация](https://scikit-learn.org/stable/modules/feature_selection.html#feature-selection)
# </div>
# </div>

# %% [markdown]
# Посмотри на признаки которые заметно коррелируют с целевой переменной. Для этого напишем функцию, которая будет строить
# * Скрипичную диаграмму
# * Гистограмму, если количество уникальных значений меньше 25
# * Выводить значение корреляции с целевой переменной

# %%
def violent_plot(df, column, target):
    plt.figure(figsize = (12, 10))
    sns.violinplot(
        x = target,
        y = column,
        data = df,
        kind = "violin",
        split = True,
        palette = "coolwarm"
    )
    plt.show()

    if df[column].nunique() <= 25:
        plt.figure(figsize = (12, 10))
        sns.histplot(data=df,
                     x=column,
                     binwidth=1,
                     hue=target)
        plt.show()

    print()
    print('Корреляция Phik:', np.round(phik_overview.loc[column]['target'], 2))
    print('-----------------------------------------------------------------------------------------------')
    print()

# %% [markdown]
# Посмотрим на корреляцию **end_begin_diff** и **target**

# %%
violent_plot(df, 'end_begin_diff','target')
# Out:
# Корреляция Phik: 0.37
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# Как мы видим те кто уходят чаще всего мало или наоборот долго пользуются услугами оператора связи. В то время как действующие пользователи в среднем пользуются 1000 дней

# %% [markdown]
# Посмотрим как влияет наличие супруга/супруги у  на целевую переменную

# %%
violent_plot(df, 'partner','target')
# Out:
# Корреляция Phik: 0.23
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# Если у пользователя есть супруга/супруга, то такие пользователи чаще уходят

# %% [markdown]
# Посмотрим как общие расходы абонента влияют на целевую переменную

# %%
violent_plot(df, 'total_charges','target')
# Out:
# Корреляция Phik: 0.3
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# У пользователей которые остались у данного оператор связи меньше расход денег, может имеет смысл дать рекомендации пользователям которые ушли, что они могут более экономно пользоваться услугами и сделать программу акцию "возвращения"

# %% [markdown]
# Посмотрим как тип оплаты платеже влияет на то, уйдет ли человек от оператора связи или нет

# %%
violent_plot(df, 'payment_method','target')
# Out:
# Корреляция Phik: 0.21
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# Тут более менее все одинаково, но можно заметить что люди которые оплачивают с помощью электронного чека на почту более редко отказываются от услуг оператора связи

# %% [markdown]
# ### Выводы по EDA
# * С каждым годом все меньше людей начинают пользоваться услугами оператора связи, так же c каждым годом все больше людей расторгают договоры с оператором
# * Создали новый признак *count_services*, который показывает сколько интернет услуг было подключено у пользователя
# * Так же добавили признак *internet_connected*, который показывает подключены ли услуги интернета у пользователя

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Разделим данные на выборки

# %%
features = df.drop('target', axis=1)
target = df['target']

# %% [markdown]
# Разделим данные в соотношение размера тренировочной выборки к тестовой - 3 к 1

# %%
features_train, features_test, target_train, target_test = train_test_split(
    features, target,
    test_size=0.25,
    stratify=target,
    random_state=RANDOM_STATE)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 1</b>: При разбиении на выборки лучше применять стратификацию по целевой переменной (stratify=target) и проверять баланс классов в полученных выборках.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Добавил параметр stratify в train_test_split, проверил баланс классов чуть ниже
# </div>

# %% [markdown]
# Проверим размеры полученных выборок

# %%
print('features_train:',features_train.shape[0])
print('target_train:',target_train.shape[0])
print()
print('features_test:',features_test.shape[0])
print('target_test:',target_test.shape[0])
# Out:
# features_train: 5282
# target_train: 5282
#
# features_test: 1761
# target_test: 1761

# %% [markdown]
# Проверим баланс классов

# %%
print('Тренировочная выборка:')
display(target_train.value_counts(normalize=True))

print('Тестовая выборка:')
display(target_train.value_counts(normalize=True))
# Out:
# Тренировочная выборка:
# 0    0.84362
# 1    0.15638
# Name: target, dtype: float64
# Тестовая выборка:
# 0    0.84362
# 1    0.15638
# Name: target, dtype: float64

# %% [markdown]
# Для кодирования и масштабирования, попробуем *make_column_transformer*

# %%
df
# Out:
#                  payment_method  monthly_charges  total_charges  \
# 0              Electronic check            29.85          31.04
# 1                  Mailed check            56.95        2071.84
# 2                  Mailed check            53.85         226.17
# 3     Bank transfer (automatic)            42.30        1960.60
# 4              Electronic check            70.70         353.50
# ...                         ...              ...            ...
# 7038               Mailed check            84.80        2035.20
# 7039    Credit card (automatic)           103.20        7430.40
# 7040           Electronic check            29.60         325.60
# 7041               Mailed check            74.40         520.80
# 7042  Bank transfer (automatic)           105.65        7251.82
#
#       senior_citizen partner multiple_lines  target  end_begin_diff  \
# 0                  0     Yes            NCP       0            31.0
# 1                  0      No             No       0          1036.0
# 2                  0      No             No       0           123.0
# 3                  0      No            NCP       0          1371.0
# 4                  0      No             No       0           153.0
# ...              ...     ...            ...     ...             ...
# 7038               0     Yes            Yes       0           730.0
# 7039               0     Yes            Yes       0          2191.0
# 7040               0     Yes            NCP       0           337.0
# 7041               1     Yes            Yes       0           215.0
# 7042               0      No             No       0          2010.0
#
#       count_services
# 0                  1
# 1                  2
# 2                  2
# 3                  3
# 4                  0
# ...              ...
# 7038               5
# 7039               4
# 7040               1
# 7041               0
# 7042               5
#
# [7043 rows x 9 columns]

# %%
num = ['monthly_charges', 'total_charges', 'end_begin_diff']
categorical = ['payment_method',
               'senior_citizen', 'partner',
               'multiple_lines', 'count_services']
col_transformer = make_column_transformer( 
    ( 
        OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), 
        categorical
    ), 
    ( 
        StandardScaler(), 
        num
    ), 
    verbose_feature_names_out=False 
)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 1:</b> При использовании elect_dtypes(include='object') куда попадет признак senior_citizen?</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# В обработку StandardScaler, ошибку понял
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 1</b>: Для деревянных моделей, включая бустинги над решающими деревьями, для кодирования категориальных признаков лучше подходит порядковое кодирование OrdinalEncoder, так как оно дает алгоритму обучения больше вариантов для поиска оптимального разбиения при построении дерева. OneHotEncoder обязателен для линейных моделей.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# теперь осуществляеться кодирование с помощью OrdinalEncode
# <div class="alert alert-block alert-warning">
# ⚠️ <b>Ревью 2</b>: Жаль, что из проекта была удалена линейная модель с OHE. Жаль, что финальный проект не используется на полную для получения нового опыта.
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# В проекте не было линейной модели
# <div class="alert alert-block alert-warning">
# ⚠️ <b>Ревью 3</b>: Жаль, что в проекте не было линейной модели с OHE. Для неё нужен был бы отдельный конвейер.
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <b>Ревью 1</b>: Для деревянных моделей, включая бустинги, масштабирование признаков необязательно, так как деревья устойчивы к разнному масштабу признаков в отличии от линейных моделей. Иногда для числовых признаков можно применить сглаживание выбросов (RobustScaler) и приведение распределения к нормальному (PowerTransformer).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 1</b>: Кодирование сразу всей обучающей выборки перед кросс-валидацией является утечкой данных из валидационных фолдов в обучающие. Лучше объединять кодировщики, другие объекты преобразования признаков, включая масштабирование, и модель в конвейер для более объективной оценки модели и подбора оптимальных гиперпараметров. Ссылку на пример кода с конвейерами давал в Пачке.</s>
# </div>
#
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 1</b>: Масштабирование признаков сразу всей обучающей выборки перед кросс-валидацией является утечкой данных из валидационных фолдов в обучающие. Лучше объединять кодировщики, другие объекты преобразования признаков, включая масштабирование, и модель в конвейер для более объективной оценки модели и подбора оптимальных гиперпараметров.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сделал кодирование и масштабирование ниже
# </div>

# %% [markdown]
# ## Обучение моделей машинного обучения

# %% [markdown]
# Обучим 3 модели машинного обучения:
# * DecisionTreeClassifier
# * RandomForestClassifier
# * CatBoostClassifier

# %% [markdown]
# ### DecisionTreeClassifier

# %% [markdown]
# Создадим переменную **params** в которой будут гиперпараметры среди которых мы будем искать лучшие

# %%
params = {'decisiontreeclassifier__max_depth' : [1, 5,10, 25, 50],
           'decisiontreeclassifier__min_samples_split' : [2,4,6],
           'decisiontreeclassifier__min_samples_leaf' : [1,2,3],
           'decisiontreeclassifier__class_weight' : ['balanced']
         }

# %% [markdown]
# С помощью **GridSearchCV** найдем лучшие параметры которые мы задали в **params**, выведем лучшую оценку ROC-AUC

# %%
model_DTC = DecisionTreeClassifier(random_state=RANDOM_STATE)
pipeline_DTC = make_pipeline(col_transformer, model_DTC)

DTC_gscv = GridSearchCV(pipeline_DTC, params, cv=3, scoring='roc_auc')
DTC_gscv.fit(features_train, target_train)

print('Лучшее значение метрики:', round(DTC_gscv.best_score_, 3),'\n')
print('Подобранные гиперпараметры модели')
DTC_gscv.best_params_
# Out:
# Лучшее значение метрики: 0.751
#
# Подобранные гиперпараметры модели
# {'decisiontreeclassifier__class_weight': 'balanced',
#  'decisiontreeclassifier__max_depth': 5,
#  'decisiontreeclassifier__min_samples_leaf': 1,
#  'decisiontreeclassifier__min_samples_split': 2}

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 2</b>: Некоторые гиперпараметры найдены на границе сетки. Может за границей есть значения лучше? В таких случаях сетку смещают в сторону границы, чтобы убедиться в оптимальности найденных значений.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Добавил значения для depth, если добавлять для остальных значений ругаться начинает
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# ❌ <s><b>Ревью 1</b>:
#
# - На экран нужно выводить подобранные гиперпараметры моделей (best_params_).
# - Лучшую метрику лучше брать из DTC_gscv.best_score_</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Исправил
# </div>

# %% [markdown]
# ### RandomForestClassifier

# %% [markdown]
# Создадим переменную **params** в которой будут гиперпараметры среди которых мы будем искать лучшие

# %%
params = [{ 'randomforestclassifier__n_estimators' : [50,100,200,400],
           'randomforestclassifier__max_depth' : [10, 25, 50],
           'randomforestclassifier__min_samples_split' : [2,4,6],
           'randomforestclassifier__min_samples_leaf' : [1,2,3],
           'randomforestclassifier__class_weight' : ['balanced']
         }]

# %% [markdown]
# С помощью **GridSearchCV** найдем лучшие параметры которые мы задали в **params**, выведем лучшую оценку ROC-AUC

# %%
model_RFC = RandomForestClassifier(random_state=RANDOM_STATE)
pipeline_RFC = make_pipeline(col_transformer, model_RFC)

RFC_gscv = GridSearchCV(pipeline_RFC, params,cv=3, scoring='roc_auc')
RFC_gscv.fit(features_train, target_train)

print('Лучшее значение метрики:', round(RFC_gscv.best_score_, 3),'\n')
print('Подобранные гиперпараметры модели')
RFC_gscv.best_params_
# Out:
# Лучшее значение метрики: 0.792
#
# Подобранные гиперпараметры модели
# {'randomforestclassifier__class_weight': 'balanced',
#  'randomforestclassifier__max_depth': 10,
#  'randomforestclassifier__min_samples_leaf': 3,
#  'randomforestclassifier__min_samples_split': 2,
#  'randomforestclassifier__n_estimators': 200}

# %% [markdown]
# ### CatBoostClassifier

# %% [markdown]
# Создадим переменную **params** в которой будут гиперпараметры среди которых мы будем искать лучшие

# %%
params = [{'catboostclassifier__verbose': [False],
          'catboostclassifier__random_state': [RANDOM_STATE],
          'catboostclassifier__learning_rate': [0.01, 0.25, 0.5, 0.75, 1],
          'catboostclassifier__depth': np.arange(1, 10),
          'catboostclassifier__subsample': np.arange(0.05, 1, 0.31)
         }]

# %% [markdown]
# С помощью **GridSearchCV** найдем лучшие параметры которые мы задали в **params**, выведем лучшую оценку ROC-AUC

# %%
model_CBC = CatBoostClassifier(random_state=RANDOM_STATE)
pipeline_CBC = make_pipeline(col_transformer, model_CBC)

CBC_gscv = GridSearchCV(pipeline_CBC, params,cv=3, scoring='roc_auc')
CBC_gscv.fit(features_train, target_train)

print('Лучшее значение метрики:', round(CBC_gscv.best_score_, 3),'\n')
print('Подобранные гиперпараметры модели')
CBC_gscv.best_params_
# Out:
# Лучшее значение метрики: 0.907
#
# Подобранные гиперпараметры модели
# {'catboostclassifier__depth': 2,
#  'catboostclassifier__learning_rate': 0.25,
#  'catboostclassifier__random_state': 27112023,
#  'catboostclassifier__subsample': 0.98,
#  'catboostclassifier__verbose': False}

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 2</b>: У CatBoostClassifier есть много других гиперпараметров, которые могут улучшить качество модели.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Добавил гиперпараметров
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# ❌ <s><b>Ревью 1</b>: Для всех моделей нужно задавать random_state</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сделал
# </div>

# %% [markdown]
# ## Выбор лучшей модели

# %% [markdown]
# features_train = pd.DataFrame(
#     col_transformer.fit_transform(features_train),
#     columns=col_transformer.get_feature_names_out()
# )

# %% [markdown]
# Лучше всех показала себя модель CatBoostClassifier, с оценкой 0.907, что удовлетворяет условию заказчика ROC-AUC >= 0.85. протестируем нашу модель на тестовой выборке

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 2</b>: Округление дает не 0.87, а 0.88, но зачем оно? Три знака после запятой гораздо информативнее.</s>
# </div>

# %% [markdown]
# Инициализируем модель с лучшими параметрами, которые мы нашли выше

# %%
model = CBC_gscv.best_estimator_

# %% [markdown]
# features_test = pd.DataFrame(
#     col_transformer.transform(features_test),
#     columns=col_transformer.get_feature_names_out()
# )

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 2</b>: Зачем разрывать конвейер? Есть ведь уже готовая к использованию CBC_gscv.best_estimator_, которую обучать не нужно. Её GridSearchCV обучил после подбора гиперпараметров. Её и нужно было тестировать сразу.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Спасибо за такое количество советов по улучшению проекта
# <div class="alert alert-block alert-success">
# ✔️ <b>Ревью 3</b>: Спасибо за внимательное отношение к советам.
# </div>
# </div>

# %% [markdown]
# Посмотрим на ROC-AUC модели на тестовой выборке

# %%
roc_auc_score(target_test, model.predict_proba(features_test)[:,1])
# Out:
# 0.9424874587054937

# %% [markdown]
# ROC-AUC на тестовой выборке 0.93, что еще лучше, чем результаты на выборе модели

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <b>Ревью 3</b>: <s>0.93</s> 0.942 или 0.94
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 2</b>: Скачок метрики говорит о склонности модели к переобучению. Причины в слабом отборе признаков и подборе гиперпараметров.</s>
# </div>

# %% [markdown]
# Посмотрим оценку модели по метрике accuracy

# %%
accuracy_score(target_test, model.predict(features_test))
# Out:
# 0.9494605337876206

# %% [markdown]
# Посмотрим ROC-кривую

# %%
predicted_probalities = model.predict_proba(features_test)[:, 1]

fpr, tpr, thresholds = roc_curve(target_test, predicted_probalities)

plt.figure(figsize=(15, 9))
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')

plt.show()

# %% [markdown]
# Как мы видим график нашей модели имеет довольно большую площадь под собой что говорит нам о том, что модель правильно идентифицирует большинство ушеднших пользователей

# %% [markdown]
# <div class="alert alert-block alert-danger">
# ❌ <s><b>Ревью 1</b>: Под кривой нужно словами написать, почему модель может считаться хорошей (в задании ведь есть слово "проанализировать").</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сделал
# </div>

# %% [markdown]
# Посмотрим матрицу ошибок

# %%
cm_cbc = confusion_matrix(target_test, model.predict(features_test))
cm_cbc_data = pd.DataFrame(cm_cbc,
                           index=['Negative', 'Positive'],
                           columns=['False', 'True'])

plt.figure(figsize=(8, 4))
sns.heatmap(cm_cbc, xticklabels=cm_cbc_data.columns, yticklabels=cm_cbc_data.index, annot=True, fmt='g', cmap="Reds", annot_kws={"size": 16})
plt.title("Матрица ошибок", size=18)
plt.xlabel('predictions', size=18)
plt.ylabel('target', size=18);

# %% [markdown]
# Как мы видим больше всего значений находиться в FN, что значит что модель определила 1458 людей как тех кто не ушел от оператора связи и это действительно так. Так же модель чаще ошибаеться на людях которые ушли TN, в среднем 1 раз за 3 ушедших пользователя

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <b>Ревью 2</b>:
#
# - <s>FN</s> TN
# - Заказчику потом можно рекомендовать на этапе опытной эксплуатации совместно с маркетологами подобрать порог классификации так, чтобы оптимизировать уже не метрику машинного обучения, а метрики бизнеса в денежном выражении с учетом неизвестного пока бюджета на акции по удержанию клиентов и разной цены ошибок первого и второго рода.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Не понял первый пункт
# <div class="alert alert-block alert-warning">
# ⚠️ <b>Ревью 3</b>:
#
# Больше всего значений находится не в FN (как написано под матрицей ошибок), а в TN (True Negative, истинно отрицательные предсказания - правильное (true) прогнозирование, что клиент не (negative) уйдет). Такое количество связано с дисбалансом классов. Остающихся просто в разы больше. Больше всего ошибок в FP - 80, а FN - 9. Подробности [здесь](https://academy.yandex.ru/handbook/ml/article/metriki-klassifikacii-i-regressii).
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# ❌ <s><b>Ревью 1</b>: Матрицу ошибок нужно проанализировать.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сделал
# </div>

# %%
pivot_table = pd.DataFrame({'name': model[:-1].get_feature_names_out(),
    'score': model.named_steps['catboostclassifier'].get_feature_importance()})
pivot_table.sort_values(by='score', ascending=False)
# Out:
#               name      score
# 7   end_begin_diff  71.432521
# 6    total_charges  10.313269
# 5  monthly_charges   9.640614
# 4   count_services   2.783276
# 0   payment_method   1.987192
# 2          partner   1.850293
# 3   multiple_lines   1.695283
# 1   senior_citizen   0.297551

# %% [markdown]
# Самыми важными признаками стали:
# * end_begin_diff - количество дней которые пользователь пользуеться услугами оператора связи
# * total_charges - общие расходы абонента
# * monthly_charges - расходы за месяц

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ <s><b>Ревью 2</b>: На дне таблицы важности оказались некоторые из мультиколлинеарных признаков, что подтверждает вожность отбора признаков на этапе исследовательского анализа данных, например, по тепловой карте корреляций. Если отбросить мультиколлинеарные признаки, признаковое пространство сократится, увеличится скорость работы модели, а качество как минимум не ухудшится значимо.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сделал
# </div>

# %% [markdown]
# ### Вывод:
# Мы разработали модель, которая удовлетворяет требованию заказчика ROC-AUC >= 0.85 \
# Оценки нашей модели:
# * ROC-AUC - 0.942
# * accuracy - 0.949
#
# <div class="alert alert-block alert-danger">
# ❌ <s><b>Ревью 2</b>: Указанные в выводах значения метрик не соответствуют достигнутым в коде выше. Нужно соблюсти правила округления, а лучше не делать его так грубо до второго знака.</s>
# </div>
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сделал
# </div>
# Модель намного лучше определяет людей кто не ушел от оператора связи, а среди тех кто ушел модель совершает ошибку 1 раз из 3.\
# Так же мы выяснили что у бизнеса есть проблемы, так как c каждым годом все меньше людей начинают пользоваться услугами оператора связи, так же c каждым годом все больше людей расторгают договоры с оператором.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# ❌ <s><b>Ревью 1</b>: Для лучшей модели нужно проанализировать важность признаков.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сделал выше
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# ✔️ <b>Ревью 1</b>: Алексей, начало положено. Постарался написать все замечания, которые смог увидеть после ячейки с ошибкой кода.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Заключение ментора:</b> Алексей, рад сообщить, что твой проект принят. Это значит, что ты справился с поставленной задачей. Поздравляю!
#
# Спасибо за использование phik на этапе анализа данных и выбор правильного метода кодирования категориальных признаков для деревянных моделей. Очень хорошо, что ты применил в работе технику обучения моделей с подбором гиперпараметров на кросс-валидации. Твои конвейеры для обработки признакового пространства сделали оценку моделей более объективной и помогли им обучаться прилежнее.
#
# Тема проекта действительно была интересная, а решение можно улучшать и дальше. Фактически наша задача является этапом более сложного процесса, называемого  <a href="https://newtechaudit.ru/vvedenie-v-uplift-modelirovanie">uplift-моделированием,</a> который подразумевает A/B тесты с контролем метрик, по результатам которых может корректироваться и порог классификации. Вот ещё некоторые источники по теме:
#
# - [Туториал по uplift моделированию](https://habr.com/ru/companies/ru_mts/articles/485980/)
# - [Курс на ODS](https://ods.ai/tracks/uplift-modelling-course)
#
# Надеюсь, что финальный проект добавил мотивации к получению новых знаний. Со своей стороны хотел бы порекомендовать тебе некоторые материалы для дальнейшего совершенствования:
#
# https://www.youtube.com/watch?v=xl1fwCza9C8 познавательное видео по настройке модели CatBoost (в ней есть много способов предотвращать переобучение);
#
# https://habr.com/ru/company/ods/blog/322626/ на Habr можно закрепить свои знания, порешав задачи из цикла статей — Открытый курс машинного обучения;
#
# https://github.com/esokolov/ml-course-hse — на гитхаб есть репозиторий с задачами из курса по машинному обучению от Евгения Соколова, можно использовать как дополнительный материал для закрепления знаний.
#
# https://habr.com/ru/company/avito/blog/571094/ — материалы по A/B тестам.
#
# Также хочу поделиться опытом и вкратце рассказать о том, в какие направления можно подаваться на работу и какие навыки там пригодятся:
#
# Направление аналитики: хорошие знания теории вероятностей и математической статистики; базовые знания библиотек ML; уверенные знания SQL; умение решать задачи по A/B тестам; плюсом будет знание специальных инструментов для аналитики по визуализации результатов.
#
# Направление ML: уверенные знания классических моделей машинного обучения; хорошие знания SQL; понимание алгоритмов машинного обучения — как устроена модель линейной регрессии, модели случайного леса, градиентного бустинга и т.д. На собеседовании могут спросить, как работает какая-нибудь модель «под капотом», очень любят градиентный бустинг и случайный лес. Здесь точно пригодится https://academy.yandex.ru/handbook/ml - онлайн-учебник от Школы анализа данных Яндекса, в котором описаны теоретические основы работы моделей машинного обучения.
#
# В некоторых компаниях при устройстве на работу или стажировку, например в Яндексе, нужно решить тест на алгоритмические задачи. По алгоритмам есть много разных курсов, платных и бесплатных. Можно попробовать Тренировки по Алгоритмам от Яндекса https://yandex.ru/yaintern/algorithm-training (бесплатно, хороший курс). Также есть и у Практикума курс по алгоритмам.
#
# Алексей, прими ещё раз мои поздравления и пожелания новых успехов!
# </div>
